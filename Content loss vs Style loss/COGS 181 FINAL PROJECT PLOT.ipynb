# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame(data = {'style loss':[2152826.25, 41429256, 25596158], \
                           'content loss':[578170.625, 403454.65625, 398279.21875], \
                           'Method':['Gatys et al.', 'Johnson et al.', 'Huang et al.']})

# %%
df2 = pd.DataFrame(data = {'style loss':[1137480.5, 6394200, 5458692], \
                           'content loss':[277122.1875, 166356.75, 157634.71875], \
                           'Method':['Gatys et al.', 'Johnson et al.', 'Huang et al.']})

# %%
df3 = pd.DataFrame(data = {'style loss':[9387562, 157985680, 27922870], \
                           'content loss':[661542.75, 526049.5, 620335.1875], \
                           'Method':['Gatys et al.', 'Johnson et al.', 'Huang et al.']})

# %%
df4 = pd.DataFrame(data = {'style loss':[1889025, 63195388, 22034912], \
                           'content loss':[721124.5625, 539862.5, 439081.21875], \
                           'Method':['Gatys et al.', 'Johnson et al.', 'Huang et al.']})

# %%
sns.set()
fig, ax = plt.subplots(2,2,figsize = (12,10))
sns.scatterplot(x = 'style loss', y = 'content loss',data=df1, ax=ax[0][0], hue='Method', s = 100)
sns.scatterplot(x = 'style loss', y = 'content loss',data=df2, ax=ax[0][1], hue='Method', s = 100)
sns.scatterplot(x = 'style loss', y = 'content loss',data=df3, ax=ax[1][0], hue='Method', s = 100)
sns.scatterplot(x = 'style loss', y = 'content loss',data=df4, ax=ax[1][1], hue='Method', s = 100)
plt.suptitle('Abs. Differences of Losses Between Direct Style Transfer & Indirect Style Transfer')
plt.savefig('content loss vs style loss.png')
